# %%
from stopflow import *

# stop flow with reaction in 50 ul chip with no film
# blue 455 nm irradiation at 10.6 mW for each time point, then uv-vis immediately after in the same chip
# flushed with fresh starting reaction mixture and repeated for new time point

# V(Ru(bpy)3, 12.5 mM, buffer) = 240 ul
# V(BV, 25 mM, buffer) = 720 ul
# V(EDTA, saturated, buffer) = 540 ul

t = [t*30 for t in range(1, 15)] # residence times in seconds for 1-7 minutes in 30s intervals
c0 = solprop(cstock=25e-3, valiquot=720e-6, vsol=1.5e-3) # initial BV2+ concentration
film = 'blank PVAc'
light = 'blue'
wavelength = 455e-9 # m
power = 10.7e-3 # W
x = 'B'

data = f'./results/260708_Rubpy_BV_EDTA_StopFlow/'
concvstimeplot(data, t, c0, x, film, light, wavelength, power, i=10)
lncvstimeplot(data, t, c0, x, film, light, wavelength, power, i=10)
spectrumvstimeplot(data, t, c0, x, film, light, wavelength, power)
