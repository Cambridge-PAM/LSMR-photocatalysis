# %%
from functions import *
a = beerlambert(c=0.3e-3, e=9.23e6, l=800e-6)
print(f'Fluorescein: {10**(2-a):.2f} % transmittance in l = 800 μm chamber')
a = beerlambert(c=0.3e-3, e=11.2e6, l=800e-6)
print(f'Eosin Y: {10**(2-a):.2f} % transmittance in l = 800 μm chamber')
# Out:
# Fluorescein: 0.61 % transmittance in l = 800 μm chamber
# Eosin Y: 0.21 % transmittance in l = 800 μm chamber

# %%
a = beerlambert(c=0.03e-3, e=9.23e6, l=1e-2)
print(f'Fluorescein: {10**(2-a):.2f} % transmittance in l = 1 cm chamber')
a = beerlambert(c=0.02e-3, e=11.2e6, l=1e-2)
print(f'Eosin Y: {10**(2-a):.2f} % transmittance in l = 1 cm chamber')
# Out:
# Fluorescein: 1.43 % transmittance in l = 1 cm chamber
# Eosin Y: 0.58 % transmittance in l = 1 cm chamber
